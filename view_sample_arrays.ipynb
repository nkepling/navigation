# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import *
from fo_solver import *
import pickle
import os
from eval import get_vi_path
from scipy.ndimage import label, center_of_mass
import pandas as pd


sample_arr_dir = "/Users/nathankeplinger/Documents/Vanderbilt/Research/ANSR/sample_arrays/"

drone_height = 10
n = 400 

cluster_sizes_list = []

df = pd.DataFrame(columns=['example_name', 'num_clusters', ''])

# Loop through each file in the directory
for example in os.listdir(sample_arr_dir):
    full_path = os.path.join(sample_arr_dir, example)
    
    with open(full_path, 'rb') as f:
        sample_arr = pickle.load(f)
    
    # Extract obstacles map
    obstacles = sample_arr['obstacleMap_array'] > drone_height

    rewards = sample_arr['targetMap_array']

    fov_cells = get_fov((100,100),(100,101),n)

    print(fov_cells) 

    visualize_rewards(rewards, obstacles,start=(0,0),goal=(n-1,n-1))
    # Label clusters in the obstacle map
    labeled_array, num_clusters = label(obstacles)

    # Calculate the size of each cluster
    cluster_sizes = np.bincount(labeled_array.ravel())[1:]  # Exclude background (label 0)
    cluster_sizes_list.extend(cluster_sizes)

    plt.figure(figsize=(10, 6))

    print("Number of clusters: ", len(cluster_sizes_list))
    plt.hist(cluster_sizes, bins=50, edgecolor='black')
    plt.xlabel('Cluster Size')
    plt.ylabel('Frequency')
    plt.title('Histogram of Cluster Sizes')
    plt.grid(True)
    plt.show()




# Plotting the histogram of cluster sizes



    # start_time = time.time()
    # Viter = value_iteration(n, rewards, obstacles, gamma,neighbors)
    # policy = extract_policy(Viter, obstacles,neighbors,n=n)
    # end_time = time.time()
    # print("Time to solve: ", end_time - start_time)


    # Solve the problem
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from utils import *
#       4 from fo_solver import *
#       5 import pickle
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/utils.py:8
#       6 import yaml
#       7 import scipy
# ----> 8 import torch
#       9 """
#      10 Takes config: single double random
#      11 and size n as inputs
#      12 """
#      14 # n = None
#      15 # config = None
#      16 # num_blocks = None
#    (...)
#      20 # random_map = None
#      21 # gamma = None
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/__init__.py:2143
#    2141 from . import library
#    2142 if not TYPE_CHECKING:
# -> 2143     from . import _meta_registrations
#    2145 # Enable CUDA Sanitizer
#    2146 if 'TORCH_CUDA_SANITIZER' in os.environ:
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/_meta_registrations.py:9
#       7 import torch._prims_common as utils
#       8 from torch import SymBool, SymFloat, Tensor
# ----> 9 from torch._decomp import (
#      10     _add_op_to_registry,
#      11     _convert_out_params,
#      12     global_decomposition_table,
#      13     meta_table,
#      14 )
#      15 from torch._ops import OpOverload
#      16 from torch._prims import _prim_elementwise_meta, ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/_decomp/__init__.py:245
#     241             decompositions.pop(op, None)
#     244 # populate the table
# --> 245 import torch._decomp.decompositions
#     246 import torch._refs
#     249 # See NOTE [Core ATen Ops]
#     250 #
#     251 # list was copied from torch/_inductor/decomposition.py
#     252 # excluding decompositions that results in prim ops
#     253 # Resulting opset of decomposition is core aten ops
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/_decomp/decompositions.py:12
#       9 from typing import Any, Callable, cast, Iterable, List, Optional, Tuple, Union
#      11 import torch
# ---> 12 import torch._prims as prims
#      13 import torch._prims_common as utils
#      14 import torch.nn.functional as F
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/_prims/__init__.py:504
#     496     raise NotImplementedError
#     499 #
#     500 # Elementwise unary operations
#     501 #
# --> 504 abs = _make_elementwise_unary_prim(
#     505     "abs",
#     506     impl_aten=torch.abs,
#     507     doc="",
#     508     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.COMPLEX_TO_FLOAT,
#     509 )
#     511 acos = _make_elementwise_unary_prim(
#     512     "acos",
#     513     impl_aten=torch.acos,
#     514     doc="",
#     515     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     516 )
#     518 acosh = _make_elementwise_unary_prim(
#     519     "acosh",
#     520     impl_aten=torch.acosh,
#     521     doc="",
#     522     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     523 )
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/_prims/__init__.py:472, in _make_elementwise_unary_prim(name, type_promotion, **kwargs)
#     465 def _make_elementwise_unary_prim(
#     466     name: str, *, type_promotion: ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND, **kwargs
#     467 ):
#     468     """
#     469     Creates an elementwise unary prim.
#     470     """
# --> 472     return _make_prim(
#     473         schema=f"{name}(Tensor self) -> Tensor",
#     474         meta=partial(_prim_elementwise_meta, type_promotion=type_promotion),
#     475         return_type=RETURN_TYPE.NEW,
#     476         **kwargs,
#     477     )
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/_prims/__init__.py:320, in _make_prim(schema, return_type, meta, impl_aten, doc, tags, use_old_custom_ops_api)
#     318         if arg.alias_info is not None and arg.alias_info.is_write:
#     319             mutates_args.append(arg.name)
# --> 320     prim_def = torch.library.custom_op(
#     321         "prims::" + name,
#     322         _prim_impl,
#     323         mutates_args=tuple(mutates_args),
#     324         schema=schema,
#     325     )
#     326     prim_def.register_fake(meta)
#     328 _prim_packet = getattr(torch._ops.ops.prims, name)
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/_library/custom_ops.py:142, in custom_op(name, fn, mutates_args, device_types, schema)
#     140 if fn is None:
#     141     return inner
# --> 142 return inner(fn)
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/_library/custom_ops.py:123, in custom_op.<locals>.inner(fn)
#     121     schema_str = schema
#     122 namespace, opname = name.split("::")
# --> 123 result = CustomOpDef(namespace, opname, schema_str, fn)
#     124 if schema is not None:
#     125     # Check that schema's alias annotations match those of `mutates_args`.
#     126     expected = set()
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/_library/custom_ops.py:169, in CustomOpDef.__init__(self, namespace, name, schema, fn)
#     166 self._backward_fn: Optional[Callable] = None
#     168 self._lib = get_library_allowing_overwrite(self._namespace, self._name)
# --> 169 self._register_to_dispatcher()
#     170 OPDEFS[self._qualname] = self
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/_library/custom_ops.py:473, in CustomOpDef._register_to_dispatcher(self)
#     465         raise RuntimeError(
#     466             f"There was no fake impl registered for {self}. "
#     467             f"This is necessary for torch.compile/export/fx tracing to work. "
#     468             f"Please use `{self._init_fn.__name__}.register_fake` to add an "
#     469             f"fake impl."
#     470         )
#     471     return self._abstract_fn(*args, **kwargs)
# --> 473 lib._register_fake(self._name, fake_impl, _stacklevel=4)
#     475 autograd_impl = _library.autograd.make_autograd_impl(self._opoverload, self)
#     476 lib.impl(self._name, autograd_impl, "Autograd", with_keyset=True)
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/library.py:135, in Library._register_fake(self, op_name, fn, _stacklevel)
#     133 def _register_fake(self, op_name, fn, _stacklevel=1):
#     134     r'''Registers the fake impl for an operator defined in the library.'''
# --> 135     source = torch._library.utils.get_source(_stacklevel + 1)
#     136     frame = sys._getframe(_stacklevel)
#     137     caller_module = inspect.getmodule(frame)
#
# File ~/Documents/Vanderbilt/Research/fullyObservableNavigation/env/lib/python3.10/site-packages/torch/_library/utils.py:42, in get_source(stacklevel)
#      33 def get_source(stacklevel: int) -> str:
#      34     """Get a string that represents the caller.
#      35
#      36     Example: "/path/to/foo.py:42"
#    (...)
#      40     etc.
#      41     """
# ---> 42     frame = inspect.getframeinfo(sys._getframe(stacklevel))
#      43     source = f"{frame.filename}:{frame.lineno}"
#      44     return source
#
# File /opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py:1624, in getframeinfo(frame, context)
#    1622 start = lineno - 1 - context//2
#    1623 try:
# -> 1624     lines, lnum = findsource(frame)
#    1625 except OSError:
#    1626     lines = index = None
#
# File /opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py:952, in findsource(object)
#     949     if not (file.startswith('<') and file.endswith('>')):
#     950         raise OSError('source code not available')
# --> 952 module = getmodule(object, file)
#     953 if module:
#     954     lines = linecache.getlines(file, module.__dict__)
#
# File /opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/inspect.py:878, in getmodule(object, _filename)
#     875         f = getabsfile(module)
#     876         # Always map to the name the module knows itself by
#     877         modulesbyfile[f] = modulesbyfile[
# --> 878             os.path.realpath(f)] = module.__name__
#     879 if file in modulesbyfile:
#     880     return sys.modules.get(modulesbyfile[file])
#
# File /opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/posixpath.py:396, in realpath(filename, strict)
#     393     """Return the canonical path of the specified filename, eliminating any
#     394 symbolic links encountered in the path."""
#     395     filename = os.fspath(filename)
# --> 396     path, ok = _joinrealpath(filename[:0], filename, strict, {})
#     397     return abspath(path)
#
# File /opt/homebrew/Cellar/python@3.10/3.10.15/Frameworks/Python.framework/Versions/3.10/lib/python3.10/posixpath.py:431, in _joinrealpath(path, rest, strict, seen)
#     429 newpath = join(path, name)
#     430 try:
# --> 431     st = os.lstat(newpath)
#     432 except OSError:
#     433     if strict:
#
# KeyboardInterrupt:
